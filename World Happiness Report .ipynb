# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize': [11, 11]}, font_scale=1.2)

# %%
df= pd.read_csv("C:\\Users\\go\\Downloads\\world-happiness-report-2021.csv")

# %%
df.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# Data analysis

# %%
df.iloc[70:149]
# Out:
#            Country name                  Regional indicator  Ladder score  \
# 70             Paraguay         Latin America and Caribbean         5.653
# 71           Montenegro          Central and Eastern Europe         5.581
# 72   Dominican Republic         Latin America and Caribbean         5.545
# 73         North Cyprus                      Western Europe         5.536
# 74              Belarus  Commonwealth of Independent States         5.534
# ..                  ...                                 ...           ...
# 144             Lesotho                  Sub-Saharan Africa         3.512
# 145            Botswana                  Sub-Saharan Africa         3.467
# 146              Rwanda                  Sub-Saharan Africa         3.415
# 147            Zimbabwe                  Sub-Saharan Africa         3.145
# 148         Afghanistan                          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (149, 20)

# %%
df.describe().transpose()
# Out:
#                                             count       mean           std  \
# Ladder score                                149.0   5.532839  1.073924e+00
# Standard error of ladder score              149.0   0.058752  2.200120e-02
# upperwhisker                                149.0   5.648007  1.054330e+00
# lowerwhisker                                149.0   5.417631  1.094879e+00
# Logged GDP per capita                       149.0   9.432208  1.158601e+00
# Social support                              149.0   0.814745  1.148890e-01
# Healthy life expectancy                     149.0  64.992799  6.762043e+00
# Freedom to make life choices                149.0   0.791597  1.133318e-01
# Generosity                                  149.0  -0.015134  1.506567e-01
# Perceptions of corruption                   149.0   0.727450  1.792263e-01
# Ladder score in Dystopia                    149.0   2.430000  5.347044e-15
# ...

# %%
df["Ladder score"].describe()
# Out:
# count    149.000000
# mean       5.532839
# std        1.073924
# min        2.523000
# 25%        4.852000
# 50%        5.534000
# 75%        6.255000
# max        7.842000
# Name: Ladder score, dtype: float64

# %%
df.groupby('Country name').max()[['Ladder score','Regional indicator']]
# Out:
#               Ladder score                  Regional indicator
# Country name
# Afghanistan          2.523                          South Asia
# Albania              5.117          Central and Eastern Europe
# Algeria              4.887        Middle East and North Africa
# Argentina            5.929         Latin America and Caribbean
# Armenia              5.283  Commonwealth of Independent States
# ...                    ...                                 ...
# Venezuela            4.892         Latin America and Caribbean
# Vietnam              5.411                      Southeast Asia
# Yemen                3.658        Middle East and North Africa
# Zambia               4.073                  Sub-Saharan Africa
# Zimbabwe             3.145                  Sub-Saharan Africa
#
# [149 rows x 2 columns]

# %%
df.groupby('Country name').mean()['Ladder score']
# Out:
# Country name
# Afghanistan    2.523
# Albania        5.117
# Algeria        4.887
# Argentina      5.929
# Armenia        5.283
#                ...
# Venezuela      4.892
# Vietnam        5.411
# Yemen          3.658
# Zambia         4.073
# Zimbabwe       3.145
# Name: Ladder score, Length: 149, dtype: float64

# %%
df['Ladder score'].max()
# Out:
# 7.8420000000000005

# %%
df['Ladder score'].min()
# Out:
# 2.523

# %%
df[df["Ladder score"]== 2.523000][["Country name","Regional indicator"]]
# Out:
#     Country name Regional indicator
# 148  Afghanistan         South Asia

# %%
df[df["Ladder score"]== 7.8420000000000005][["Country name","Regional indicator"]]
# Out:
#   Country name Regional indicator
# 0      Finland     Western Europe

# %%
df[df["Ladder score"] > 5.534000][["Country name","Regional indicator"]]
# notice european counteries are higher than south and east asia  countries in ladder score which is they are happier
# Out:
#           Country name           Regional indicator
# 0              Finland               Western Europe
# 1              Denmark               Western Europe
# 2          Switzerland               Western Europe
# 3              Iceland               Western Europe
# 4          Netherlands               Western Europe
# ..                 ...                          ...
# 69            Mongolia                    East Asia
# 70            Paraguay  Latin America and Caribbean
# 71          Montenegro   Central and Eastern Europe
# 72  Dominican Republic  Latin America and Caribbean
# 73        North Cyprus               Western Europe
#
# [74 rows x 2 columns]

# %%
df[df["Ladder score"] < 5.534000][["Country name","Regional indicator"]]
# Their ladder score is lower than western europe countries which means they are not happy like them.
# Out:
#                   Country name                  Regional indicator
# 75                      Russia  Commonwealth of Independent States
# 76   Hong Kong S.A.R. of China                           East Asia
# 77                  Tajikistan  Commonwealth of Independent States
# 78                     Vietnam                      Southeast Asia
# 79                       Libya        Middle East and North Africa
# ..                         ...                                 ...
# 144                    Lesotho                  Sub-Saharan Africa
# 145                   Botswana                  Sub-Saharan Africa
# 146                     Rwanda                  Sub-Saharan Africa
# 147                   Zimbabwe                  Sub-Saharan Africa
# 148                Afghanistan                          South Asia
#
# [74 rows x 2 columns]

# %%
df.groupby('upperwhisker').describe()['Ladder score'].transpose()
# Out:
# upperwhisker  2.596  3.259  3.548  3.611  3.748  3.762  3.781  3.794  3.869  \
# count         1.000  1.000  1.000  1.000  1.000  1.000    1.0  1.000  1.000
# mean          2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
# std             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# min           2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
# 25%           2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
# 50%           2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
# 75%           2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
# max           2.523  3.145  3.415  3.467  3.512  3.623    3.6  3.658  3.819
#
# upperwhisker  3.953  ...  7.337  7.355  7.396  7.433  7.462  7.518  7.643  \
# count         1.000  ...  1.000  1.000  1.000  1.000  1.000  1.000  1.000
# mean          3.615  ...  7.268  7.277  7.324  7.363  7.392  7.464  7.571
# ...

# %%
df.groupby('Country name').describe()['Ladder score'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000    1.000      1.000    1.000      1.000
# mean                2.523    5.117    4.887      5.929    5.283      7.183
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 2.523    5.117    4.887      5.929    5.283      7.183
# 25%                 2.523    5.117    4.887      5.929    5.283      7.183
# 50%                 2.523    5.117    4.887      5.929    5.283      7.183
# 75%                 2.523    5.117    4.887      5.929    5.283      7.183
# max                 2.523    5.117    4.887      5.929    5.283      7.183
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000       1.000    1.000       1.000  ...
# mean            7.268       5.171    6.647       5.025  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['upperwhisker'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000    1.000       1.00    1.000      1.000
# mean                2.596    5.234    4.991       6.04    5.397      7.265
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 2.596    5.234    4.991       6.04    5.397      7.265
# 25%                 2.596    5.234    4.991       6.04    5.397      7.265
# 50%                 2.596    5.234    4.991       6.04    5.397      7.265
# 75%                 2.596    5.234    4.991       6.04    5.397      7.265
# max                 2.596    5.234    4.991       6.04    5.397      7.265
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000        1.00    1.000       1.000  ...
# mean            7.337        5.25    6.779       5.115  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['Logged GDP per capita'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000     1.00    1.000      1.000    1.000      1.000
# mean                7.695     9.52    9.342      9.962    9.487     10.796
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 7.695     9.52    9.342      9.962    9.487     10.796
# 25%                 7.695     9.52    9.342      9.962    9.487     10.796
# 50%                 7.695     9.52    9.342      9.962    9.487     10.796
# 75%                 7.695     9.52    9.342      9.962    9.487     10.796
# max                 7.695     9.52    9.342      9.962    9.487     10.796
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000       1.000    1.000       1.000  ...
# mean           10.906       9.569   10.669       8.454  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['Social support'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000    1.000      1.000    1.000       1.00
# mean                0.463    0.697    0.802      0.898    0.799       0.94
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 0.463    0.697    0.802      0.898    0.799       0.94
# 25%                 0.463    0.697    0.802      0.898    0.799       0.94
# 50%                 0.463    0.697    0.802      0.898    0.799       0.94
# 75%                 0.463    0.697    0.802      0.898    0.799       0.94
# max                 0.463    0.697    0.802      0.898    0.799       0.94
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000       1.000    1.000       1.000  ...
# mean            0.934       0.836    0.862       0.693  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['Perceptions of corruption'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000    1.000      1.000    1.000      1.000
# mean                0.924    0.901    0.752      0.834    0.629      0.442
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 0.924    0.901    0.752      0.834    0.629      0.442
# 25%                 0.924    0.901    0.752      0.834    0.629      0.442
# 50%                 0.924    0.901    0.752      0.834    0.629      0.442
# 75%                 0.924    0.901    0.752      0.834    0.629      0.442
# max                 0.924    0.901    0.752      0.834    0.629      0.442
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000       1.000    1.000       1.000  ...
# mean            0.481       0.506    0.722       0.682  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['Freedom to make life choices'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000     1.00      1.000    1.000      1.000
# mean                0.382    0.785     0.48      0.828    0.825      0.914
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                 0.382    0.785     0.48      0.828    0.825      0.914
# 25%                 0.382    0.785     0.48      0.828    0.825      0.914
# 50%                 0.382    0.785     0.48      0.828    0.825      0.914
# 75%                 0.382    0.785     0.48      0.828    0.825      0.914
# max                 0.382    0.785     0.48      0.828    0.825      0.914
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count           1.000       1.000    1.000       1.000  ...
# mean            0.908       0.814    0.925       0.877  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df.groupby('Country name').describe()['Healthy life expectancy'].transpose()
# Out:
# Country name  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# count               1.000    1.000    1.000        1.0    1.000        1.0
# mean               52.493   68.999   66.005       69.0   67.055       73.9
# std                   NaN      NaN      NaN        NaN      NaN        NaN
# min                52.493   68.999   66.005       69.0   67.055       73.9
# 25%                52.493   68.999   66.005       69.0   67.055       73.9
# 50%                52.493   68.999   66.005       69.0   67.055       73.9
# 75%                52.493   68.999   66.005       69.0   67.055       73.9
# max                52.493   68.999   66.005       69.0   67.055       73.9
#
# Country name  Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# count             1.0       1.000    1.000         1.0  ...
# mean             73.3      65.656   69.495        64.8  ...
# std               NaN         NaN      NaN         NaN  ...
# ...

# %%
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df.corr()[['Ladder score','Ladder score in Dystopia']]
# Out:
#                                             Ladder score  \
# Ladder score                                1.000000e+00
# Standard error of ladder score             -4.707869e-01
# upperwhisker                                9.993471e-01
# lowerwhisker                                9.993963e-01
# Logged GDP per capita                       7.897597e-01
# Social support                              7.568876e-01
# Healthy life expectancy                     7.680995e-01
# Freedom to make life choices                6.077531e-01
# Generosity                                 -1.779928e-02
# Perceptions of corruption                  -4.211400e-01
# Ladder score in Dystopia                   -1.975255e-15
# Explained by: Log GDP per capita            7.897447e-01
# Explained by: Social support                7.568687e-01
# Explained by: Healthy life expectancy       7.681379e-01
# Explained by: Freedom to make life choices  6.077929e-01
# ...

# %%
### Data Visualization

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr()[['Ladder score','Ladder score in Dystopia']], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='upperwhisker', y='Ladder score', data=df)

# %%
sns.jointplot(x='Logged GDP per capita', y='Ladder score', data=df)

# %%
sns.jointplot(x='Social support', y='Ladder score', data=df)

# %%
sns.jointplot(x='Healthy life expectancy', y='Ladder score', data=df)

# %%
sns.jointplot(x='Freedom to make life choices', y='Ladder score', data=df)

# %%
sns.jointplot(x='Generosity', y='Ladder score', data=df)

# %%
sns.jointplot(x='Perceptions of corruption', y='Ladder score', data=df)

# %%
sns.jointplot(x='Explained by: Perceptions of corruption', y='Ladder score', data=df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Data preprocessing¶
# Data Cleaning or Cleansing
# Work with Missing data
# Work with Categorical data
# Split data to Train and Test Sets
# Feature Scaling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df = pd.get_dummies(df, columns=['Country name', 'Regional indicator'], drop_first=True)
df
# Out:
#      Ladder score  Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0           7.842                           0.032         7.904         7.780
# 1           7.620                           0.035         7.687         7.552
# 2           7.571                           0.036         7.643         7.500
# 3           7.554                           0.059         7.670         7.438
# 4           7.464                           0.027         7.518         7.410
# ..            ...                             ...           ...           ...
# 144         3.512                           0.120         3.748         3.276
# 145         3.467                           0.074         3.611         3.322
# 146         3.415                           0.068         3.548         3.282
# 147         3.145                           0.058         3.259         3.030
# 148         2.523                           0.038         2.596         2.449
#
# ...

# %%
df.isna().sum()
# no misssing values
# Out:
# Ladder score                                0
# Standard error of ladder score              0
# upperwhisker                                0
# lowerwhisker                                0
# Logged GDP per capita                       0
#                                            ..
# Regional indicator_North America and ANZ    0
# Regional indicator_South Asia               0
# Regional indicator_Southeast Asia           0
# Regional indicator_Sub-Saharan Africa       0
# Regional indicator_Western Europe           0
# Length: 175, dtype: int64

# %%
df['Ladder score'].unique()
# Out:
# array([7.842, 7.62 , 7.571, 7.554, 7.464, 7.392, 7.363, 7.324, 7.277,
#        7.268, 7.183, 7.157, 7.155, 7.103, 7.085, 7.069, 7.064, 6.965,
#        6.951, 6.834, 6.69 , 6.647, 6.602, 6.584, 6.561, 6.494, 6.491,
#        6.483, 6.461, 6.435, 6.431, 6.377, 6.372, 6.331, 6.33 , 6.317,
#        6.309, 6.255, 6.223, 6.189, 6.18 , 6.179, 6.172, 6.166, 6.152,
#        6.14 , 6.106, 6.078, 6.061, 6.049, 6.032, 6.012, 5.992, 5.985,
#        5.972, 5.94 , 5.929, 5.919, 5.882, 5.88 , 5.845, 5.84 , 5.813,
#        5.766, 5.764, 5.744, 5.723, 5.716, 5.677, 5.653, 5.581, 5.545,
#        5.536, 5.534, 5.477, 5.466, 5.411, 5.41 , 5.384, 5.345, 5.342,
#        5.339, 5.306, 5.283, 5.269, 5.266, 5.198, 5.171, 5.142, 5.132,
#        5.117, 5.101, 5.088, 5.074, 5.066, 5.051, 5.045, 5.03 , 5.025,
#        4.984, 4.956, 4.948, 4.934, 4.918, 4.892, 4.891, 4.887, 4.875,
#        4.854, 4.852, 4.834, 4.83 , 4.794, 4.759, 4.723, 4.721, 4.636,
# ...

# %%
df.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
# Split data to Train and Test Sets

# %%
x = df.drop('Ladder score', axis=1)
y = df['Ladder score']
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
models = {
    "LR": LinearRegression(),
    "KNNR" : KNeighborsRegressor(), 
    "SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}') 
    y_pred = model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print('-----------------------------------------------------------')
# Out:
# Using model: LR
# Training Score: 1.0
# Test Score: 0.9574287089526304
# RMSE: 0.21473701470099918
# -----------------------------------------------------------
# Using model: KNNR
# Training Score: 0.8105246358692972
# Test Score: 0.7483337513088077
# RMSE: 0.5221087702768457
# -----------------------------------------------------------
# Using model: SVR
# Training Score: 0.9854170732570399
# Test Score: 0.7698274545806982
# RMSE: 0.49931574494628117
# -----------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.9941912523545876
# RMSE: 0.07932128760091241
# -----------------------------------------------------------
# Using model: RF
# Training Score: 0.9982112824560302
# Test Score: 0.9944145417699427
# RMSE: 0.07778178488566609
# -----------------------------------------------------------

# %%
### Testing on real data and deployment

# %%
import pickle

# %%
filename = 'model.pkl'

pickle.dump(model, open(filename, 'wb'))

# %%
x.columns
# Out:
# Index(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        ...
#        'Country name_Zimbabwe',
#        'Regional indicator_Commonwealth of Independent States',
#        'Regional indicator_East Asia',
#        'Regional indicator_Latin America and Caribbean',
#        'Regional indicator_Middle East and North Africa',
#        'Regional indicator_North America and ANZ',
#        'Regional indicator_South Asia', 'Regional indicator_Southeast Asia',
#        'Regional indicator_Sub-Saharan Africa',
#        'Regional indicator_Western Europe'],
#       dtype='object', length=174)
